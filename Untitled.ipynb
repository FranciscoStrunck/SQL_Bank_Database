# %%
import csv

# %%
with open('dados/transactions.csv', 'r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        for value in row:
            print(value)
# Out:
# transaction_id;"account_id";"transaction_type";"transaction_date";"amount";"fraudulent"
# 1;11;"cartão de crédito";"1992-01-19";-528.45;1
# 2;14;"cartão de crédito";"1920-10-15";-52.29;0
# 3;2;"PIX";"1992-11-23";-152.99;0
# 4;15;"cartão de crédito";"1991-09-16";-81.02;0
# 5;8;"cartão de débito";"1961-11-15";-572.73;0
# 6;9;"cartão de débito";"1987-01-17";-162.29;0
# 7;8;"PIX";"1969-07-31";544.05;0
# 8;9;"cartão de crédito";"1983-11-30";-233.45;0
# 9;15;"cartão de crédito";"1986-01-26";-37.88;0
# 10;2;"PIX";"1991-01-30";-390.3;1
# 11;16;"PIX";"1921-02-26";-7.69;0
# 12;10;"PIX";"1925-08-17";-236.06;0
# 13;6;"PIX";"2001-07-27";-23.84;0
# 14;8;"cartão de débito";"1969-12-15";-213.82;0
# 15;6;"PIX";"2009-10-05";-432.12;1
# 16;10;"PIX";"1921-01-27";-609.72;0
# 17;16;"cartão de crédito";"1925-04-12";-176.64;0
# 18;6;"PIX";"2006-06-15";-155.68;0
# 19;12;"cartão de crédito";"1927-05-24";-67.67;0
# 20;11;"PIX";"1991-05-09";-186.41;0
# 21;15;"PIX";"1992-06-12";-75.26;0
# ...

# %%
print(csv_reader)

# %%
import pandas as pd

# Read the CSV file
data_frame = pd.read_csv('dados/transactions.csv', encoding='latin1', delimiter=';')

# Access the data in the dataframe
data_frame
# Out:
#        transaction_id  account_id   transaction_type transaction_date  amount  \
# 0                   1          11  cartão de crédito       1992-01-19 -528.45
# 1                   2          14  cartão de crédito       1920-10-15  -52.29
# 2                   3           2                PIX       1992-11-23 -152.99
# 3                   4          15  cartão de crédito       1991-09-16  -81.02
# 4                   5           8   cartão de débito       1961-11-15 -572.73
# ...               ...         ...                ...              ...     ...
# 19995           19996           2  cartão de crédito       1990-09-28 -348.49
# 19996           19997          17  cartão de crédito       1991-09-26 -130.51
# 19997           19998          11                PIX       1991-12-30 -223.12
# 19998           19999           5                PIX       2006-01-19  -89.16
# 19999           20000           5  cartão de crédito       2000-08-17 -277.65
#
#        fraudulent
# ...
